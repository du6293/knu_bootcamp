# %% [markdown]
# ### **코랩** 한글문제 해결

# %%
# 나눔바른고딕 폰트 설치 - 런타임 연결이 다시 될 때마다 다시 폰트를 설치해야 한글이 보입니다.
# !apt-get install fonts-nanum

# %%
# 한글폰트 설치하기 위해 필요함
import matplotlib.font_manager as fm

fm.fontManager.addfont('/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf')
plt.rcParams['font.family'] = "NanumBarunGothic"

# %%
# warning메시지 무시
import warnings
warnings.filterwarnings('ignore')

# %%
# 음수부호 표시하도록 설정
plt.rc("axes", unicode_minus = False)

# %% [markdown]
# #1 Matplotlib

# %% [markdown]
# ![그림1.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##1.1 Line Plot

# %% [markdown]
# 시간에 따른 데이터의 연속적인 변화량을 관찰하고자 할 때 주로 사용:트렌드(추세)
#
#
#
# ```
# plt.plot([x],y,[fmt])
# ```

# %% [markdown]
# 스타일 문자열은 color, marker, line style 순서로 지정, 생략하면 디폴트값이 적용

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![그림2.png](data:image/png;base64,...)

# %% [markdown]
# ## Subplot

# %% [markdown]
# [도전] 아래 그래프를 그려보세요

# %% [markdown]
# ![이미지 24.png](data:image/png;base64,...)

# %% [markdown]
# ##1.2 Scatter Plot

# %% [markdown]
# 두 변수의 상관관계를 보기위해 좌표계의 평면에 데이터를 점으로 표현하는 그래프
#
# 2차원 데이터 즉, 두 개의 실수 데이터 집합의 상관관계를 살펴보고자 할 때 주로 사용, 이상치 확인 쉬움
#
# ```
# plt.scatter(x,y,[s,c,marker, aplha])
# s: 마커 크기, c:마커 색, marker: 마커의 모양, alpha:투명도 0-1
# ```

# %% [markdown]
# ### 실습 I

# %% [markdown]
# P93 몸무게 변화 그래프 그리기
# weight.csv 업로드
#
# weight.csv 파일을 읽어와서 날짜별로 몸무게를 계한사여 아래와 같은 몸무게 변화그래프를 그려보세요. (몸무게 계산은 human class 이용)

# %% [markdown]
# ### 실습II
# 엔진크기와 연비와의 관례를 산점도 그래프로 그리기
# mpg.csv 파일 업로드
#
#
# 1999년 ~2008년도의 가장 대중적인 자동차모델 38개에 대한연비 효율데이터를 읽어와서 엔지 크기와 연비와의 관계룰 산점도 그래프로 그리세요

# %% [markdown]
# ##1.3 Bar Plot

# %% [markdown]
# 값을 막대의 높이로 나타내므로 여러 항목의 수량이 많고 적음을 한눈에 알아보기 쉬워 여러 항목 데이터를 비교할 대 주로 사용
#
#
#
# ```
# plt.bar(x, height [,width, color, tick_label, align, label])
#
# x: height 와 길이가 일치하는 데이터로 x축에 표시될 위치를 지정
# height: 막대로 표시할 데이터
# width: 막대의 폭을 지정(0~1사이의 실수를 지정, 기본값 0.8)
# color:막대그래프의 색깔을 지정
# tick_label:막대그래프 각각의 이름을 지정(기본값: 숫자)
# align: x위치를 기준으로 막대그래프의 정렬(기본값:center)
# Label: 범례에 표시할 이름을 지정
# ```

# %% [markdown]
# 제주도 지역의 2010년 ~ 2012년 방문한 내국인과 외국인 통계자료

# %% [markdown]
# [도전] 위의 그래프를 barh()함수를 이용해서 수평막대그래프를 그리세요.

# %% [markdown]
# ##1.4 Pie Chart

# %% [markdown]
# 범주형 데이터들이 가지는 전체 비율을 한눈에 보고자 할때 적절한 그래프

# %% [markdown]
# ##1.5 HeatMap

# %% [markdown]
# 이미지 위에 열분포 형태로 정보를 표현하는 방법

# %% [markdown]
# ##1.6 Histogram

# %% [markdown]
# 주어진 자료를 몇 개의 구간으로 나누고 각 구간의 도수를 조사하여 나타낸 막대 그래프

# %% [markdown]
# 히스토그램으로 정규분포함수 그리기

# %% [markdown]
# 정규 분포(normal distribution)란 연속 확률 분포의 하나이며 평균이 0이고 분산이 1인 정규 분포를 표준 정규 분포

# %% [markdown]
# ### 실습 III

# %% [markdown]
# 2010년 부터 10년간 울릉도 지역의 기온과 바람세기를 측정한 데이터(weather.csv 업로드)를 pandas 를 이용하여 읽고 연도별 평균기온을 히스토그램으로 출력하세요.
#
# (힌트 groupby(), DatetimeIndex(), plt.bar())

# %% [markdown]
# ##1.7 Box Plot

# %% [markdown]
# 최대, 최소, 중간값과 사분위 수 등의 통계량을 하나의 상자 그림으로 그림

# %% [markdown]
# ![이미지 9.png](data:image/png;base64,...)

# %% [markdown]
# ## 1.8 그래프의 크기와 그리드

# %% [markdown]
# 100개의 난수를 가진 데이터 10종을 만들어 각각의 box plot으로 그리기

# %% [markdown]
# ## 실습 IV

# %% [markdown]
# 1.   정규분포를 가지는 10,000개의 난수를 생성하여 다음과 같은 f1, f2 다차원 배열을 만들어보고 아래와 같이 히스토그램을 그려보세요

# %% [markdown]
# 2-1 대표적인 주기함수인 사인 함수를 사용하여 다음 그림과 같은 히트맵을 그려보도록 하자. 격자의 크기는 10x10 이며, 사인 함수의 입력값의 구간은 0에서 pi 사이이다.

# %% [markdown]
# ![그림4.png](data:image/png;base64,...)

# %% [markdown]
# 2-2 사인 함수를 사용하여 100x100 크기의 격자공간에 다음과 같은 패턴이 나타나도록 위의 코드를 수정하여라.

# %% [markdown]
# ![그림5.png](data:image/png;base64,...)

# %% [markdown]
# 3 난수를 1,0000개 발생시켜 임의의 2차원 좌표를 생성해 그려보자. 이때 좌표의 x와 y 값은 표준정규분포를 따르도록 할 것이다. 그러면 생성된 좌표는 원점 (0,0)에 밀집한 모양을 가질 것이다.

# %% [markdown]
# 3-1 scatter() 함수 내에 불투명도를 의미하는 alpha 키워드 매개변수를 0.01로 두고 그림을 그려보자

# %% [markdown]
# ![그림6.png](data:image/png;base64,...)

# %% [markdown]
# 3-2 alpha 키워드 매개변수를 0.1로 두고 색상을 ‘magenta’로 두어 심홍색 점이 진하게 보이도록 그려보자

# %% [markdown]
# #2 seaborn

# %% [markdown]
# Matplotlib을 기반으로 만들어졌으며, Matplotlib에 비하여 높은 수준의 인터페이스를 제공하여 사용자들이 보다 쉽게 데이터를 분석하고 시각화 할 수 있음

# %% [markdown]
# ![이미지 11.png](data:image/png;base64,...)

# %% [markdown]
# ##1 Tips 데이터로 seaborn 시작하기
#
# 식당에서 식사하고 지불한 팁

# %% [markdown]
# relplot은 산점도와 선그래프 모두 그릴수 있는 함수 (kind='scatter'|'line')
#
# (https://seaborn.pydata.org/generated/seaborn.relplot.html)

# %% [markdown]
# Facetgrid
#
# 다양한 범주형 값을 가지는 데이터를 시각화하는데 좋은 방법, 여러 개의 AxesSubplot를 포함

# %% [markdown]
# 선형회귀직선

# %% [markdown]
# 변수 사이의 관계를 알아보기에 편리한 쌍그래프

# %% [markdown]
# 기본적으로 이 함수는 의 각 숫자 변수 data가 단일 행의 y축과 단일 열의 x축에서 공유되도록 축 그리드를 생성합니다. 대각선 플롯은 다르게 처리됩니다. 일변량 분포 플롯은 각 열에 있는 데이터의 주변 분포를 표시하기 위해 그려집니다.

# %% [markdown]
# 시본 라이브러리의 pairplot() 함수에 kind='hist' 키워드 인자를 추가하여 왼쪽 그림과 같이 표시하여라. 다음으로 kind='kde'를 사용하여 쌍플롯을 그려 보아라.

# %% [markdown]
# ##2  Anscombe’s quartet 데이터 셋

# %% [markdown]
# 1973년 통계학자인 프란시스 앤스컴Francis Anscombe이 데이터 분석에 앞서 시각화의 중요성과 특이치 값의 영향을 보여주기 위해 만든 데이터셋
#
# https://ko.wikipedia.org/wiki/%EC%95%A4%EC%8A%A4%EC%BB%B4_%EC%BD%B0%EB%A5%B4%ED%85%9F

# %% [markdown]
# ![그림8.png](data:image/png;base64,...)

# %% [markdown]
# lmplot은 regplot과 유사한 선형 회귀 직선을 구하는 기능과 함께 FacetGrid라고 하는 화면에 보기 좋은 격자간격을 생성하는 인터페이스를 결합한 함수

# %% [markdown]
# 비선형 함수를 사용 order = 2

# %% [markdown]
# 이상치 존재

# %% [markdown]
# lmplot() 함수를 robust=True 키워드 인자를 사용하면 이상치에 덜 민감한 강건한 모델을 만듦

# %% [markdown]
# ## 실습 I

# %% [markdown]
# ###1.시본의 lmplot() 함수를 사용하여 다음과 같이 tip 데이터를 시각화 하여라. 이 데이터는 다음과 같이 smoker 값의 Yes/No에 따라서 서로 다른 선형 회귀 직선이 하나의 그래프에 나타난다.

# %% [markdown]
# ![그림10.png](data:image/png;base64,...)

# %% [markdown]
# ###2 타이타닉 데이터를 가져와서 아래와 같이 시각화 해보기

# %% [markdown]
# ###2-1 타이타닉 데이터를 분석하여 다음과 같이 각 선실 등급별 남자, 여자, 어린이 데이터를 시각화하세요. (힌트: seaborn countplot())

# %% [markdown]
# ###2-2 col=‘survived’ 키워드 인자를 이용하여 사망자와 생존자의 분포 간의 차이를 시각화해 보세요.
# 힌트: relplot()

# %% [markdown]
# ![그림12.png](data:image/png;base64,...)

# %% [markdown]
# ##3 flights 데이터 셋

# %% [markdown]
# 1949~1960년 까지 월간 항공기 이용자수

# %% [markdown]
# #3 folium

# %%
# !pip install folium

# %% [markdown]
# ### 강원대 지도에서 표시

# %% [markdown]
# ### 내가 좋아하는 맛집 찾아보기
