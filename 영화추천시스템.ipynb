# %% [markdown]
# <a href="https://colab.research.google.com/github/du6293/project/blob/main/%EC%98%81%ED%99%94%EC%B6%94%EC%B2%9C%EC%8B%9C%EC%8A%A4%ED%85%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download('punkt')

from nltk.tokenize import word_tokenize
from nltk.tokenize import WordPunctTokenizer
#from tensorflow.keras.preprocessing.text import text_to_word_sequence
from nltk.corpus import stopwords
# from konlpy.tag import Okt
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
import numpy as np
import pandas as pd
from numpy.linalg import norm
import matplotlib.pyplot as plt

# %%
# warning메시지 무시
import warnings
warnings.filterwarnings('ignore')

# 나눔바른고딕 폰트 설치 - [런타임 다시 시작]되면 폰트를 다시 설치해야 한글이 보입니다.
# !apt-get install fonts-nanum

# 한글폰트 설정
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt

fm.fontManager.addfont('/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf')
plt.rcParams['font.family'] = "NanumBarunGothic"

# 마이너스(음수)부호 설정
plt.rc("axes", unicode_minus = False)
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   cuda-command-line-tools-10-0 cuda-command-line-tools-10-1
#   cuda-command-line-tools-11-0 cuda-compiler-10-0 cuda-compiler-10-1
#   cuda-compiler-11-0 cuda-cuobjdump-10-0 cuda-cuobjdump-10-1
#   cuda-cuobjdump-11-0 cuda-cupti-10-0 cuda-cupti-10-1 cuda-cupti-11-0
#   cuda-cupti-dev-11-0 cuda-documentation-10-0 cuda-documentation-10-1
#   cuda-documentation-11-0 cuda-documentation-11-1 cuda-gdb-10-0 cuda-gdb-10-1
#   cuda-gdb-11-0 cuda-gpu-library-advisor-10-0 cuda-gpu-library-advisor-10-1
#   cuda-libraries-10-0 cuda-libraries-10-1 cuda-libraries-11-0
#   cuda-memcheck-10-0 cuda-memcheck-10-1 cuda-memcheck-11-0 cuda-nsight-10-0
#   cuda-nsight-10-1 cuda-nsight-11-0 cuda-nsight-11-1 cuda-nsight-compute-10-0
#   cuda-nsight-compute-10-1 cuda-nsight-compute-11-0 cuda-nsight-compute-11-1
# ...

# %% [markdown]
# # 사용자 데이터 입력받기

# %%
movie_gn=[]


count=1
while count<3:
  gn=input(print(f'1.Action 2.Adventure 3.Fantasy 4.Drama 5.Comedy 6.Romance 7.Musical 8.Crime 9.Music 10.Family 11.Biography 12.Sci-Fi 13.War 14.Thriller 15.Mystery 16.History 17.Animation 18.Horror 19.Western 20.Sport 21.Film-Noir'))
  if gn=='1':
    movie_gn.append('Action')
    count+=1
  if gn=='2':
    movie_gn.append('Adventure')
    count+=1
  if gn=='3':
    movie_gn.append('Fantasy')
    count+=1
  if gn=='4':
    movie_gn.append('Drama')
    count+=1
  if gn=='5':
    movie_gn.append('Comedy')
    count+=1
  if gn=='6':
    movie_gn.append('Romance')
    count+=1
  if count==3:
    movie_gn=",".join(movie_gn)
    break


movie_gn
# Out:
# 1.Action 2.Adventure 3.Fantasy 4.Drama 5.Comedy 6.Romance 7.Musical 8.Crime 9.Music 10.Family 11.Biography 12.Sci-Fi 13.War 14.Thriller 15.Mystery 16.History 17.Animation 18.Horror 19.Western 20.Sport 21.Film-Noir
# 5
# 1.Action 2.Adventure 3.Fantasy 4.Drama 5.Comedy 6.Romance 7.Musical 8.Crime 9.Music 10.Family 11.Biography 12.Sci-Fi 13.War 14.Thriller 15.Mystery 16.History 17.Animation 18.Horror 19.Western 20.Sport 21.Film-Noir
# 1
# 'Comedy,Action'

# %%
2
#딕셔너리
movie_like={'상영시간':0,'장르':list(),'개봉연도':0,'영화스토리':list()}

tm=input(print(f'상영시간'))

#상영시간
movie_like['상영시간']=int(tm)

#영화장르
print(f'영화장르를 선택해주세여')
while True:
  print(f'0을 입력하시면 종료됩나다')
  gn=input(print(f'1.Action 2.Adventure 3.Fantasy 4.Drama 5.Comedy 6.Romance 7.Musical 8.Crime 9.Music 10.Family 11.Biography 12.Sci-Fi 13.War 14.Thriller 15.Mystery 16.History 17.Animation 18.Horror 19.Western 20.Sport 21.Film-Noir'))
  if gn=='1':
    movie_like['장르'].append('Action')
  if gn=='2':
    movie_like['장르'].append('Adventure')
  if gn=='3':
    movie_like['장르'].append('Fantasy')
  if gn=='4':
    movie_like['장르'].append('Drama')
  if gn=='5':
    movie_like['장르'].append('Comedy')
  if gn=='6':
    movie_like['장르'].append('Romance')
  if gn=='7':
    movie_like['장르'].append('Musical')
  if gn=='8':
    movie_like['장르'].append('Crime')
  if gn=='9':
    movie_like['장르'].append('Music')
  if gn=='10':
    movie_like['장르'].append('Family')
  if gn=='11':
    movie_like['장르'].append('Biography')
  if gn=='12':
    movie_like['장르'].append('Sci-Fi')
  if gn=='13':
    movie_like['장르'].append('War')
  if gn=='14':
    movie_like['장르'].append('Thriller')
  if gn=='15':
    movie_like['장르'].append('Mystery')
  if gn=='16':
    movie_like['장르'].append('History')
  if gn=='17':
    movie_like['장르'].append('Animation')
  if gn=='18':
    movie_like['장르'].append('Horror')
  if gn=='19':
    movie_like['장르'].append('Western')
  if gn=='20':
    movie_like['장르'].append('Sport')
  if gn=='21':
    movie_like['장르'].append('Film-Noir')
  if gn=='0':
    movie_like['장르']=",".join(movie_like['장르'])
    break
  
#개봉연도
yor=input(print(f'개봉연도를 입력해주세요'))
movie_like['개봉연도']=int(yor)

#스토리 키워드
while True:
  st=input(print('스토리의 키워드가 되는 단어들을 입력해주세요. 0을 입력하시면 종료됩니다'))
  if st=='0':
    movie_like['영화스토리']=",".join(movie_like['영화스토리'])
    break
  else:
    movie_like['영화스토리'].append(st)

#Series로 변환
movie_love=pd.Series(movie_like)
movie_love
# Out:
# 상영시간
# 1
# 영화장르를 선택해주세여
# 0을 입력하시면 종료됩나다
# 1.Action 2.Adventure 3.Fantasy 4.Drama 5.Comedy 6.Romance 7.Musical 8.Crime 9.Music 10.Family 11.Biography 12.Sci-Fi 13.War 14.Thriller 15.Mystery 16.History 17.Animation 18.Horror 19.Western 20.Sport 21.Film-Noir
# 5
# 0을 입력하시면 종료됩나다
# 1.Action 2.Adventure 3.Fantasy 4.Drama 5.Comedy 6.Romance 7.Musical 8.Crime 9.Music 10.Family 11.Biography 12.Sci-Fi 13.War 14.Thriller 15.Mystery 16.History 17.Animation 18.Horror 19.Western 20.Sport 21.Film-Noir
# 0
# 개봉연도를 입력해주세요
# 8
# 스토리의 키워드가 되는 단어들을 입력해주세요. 0을 입력하시면 종료됩니다
# dskfnas
# 스토리의 키워드가 되는 단어들을 입력해주세요. 0을 입력하시면 종료됩니다
# 0
# 상영시간           1
# 장르        Comedy
# 개봉연도           8
# 영화스토리    dskfnas
# dtype: object

# %% [markdown]
# # csv 파일 가져오기

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

data = pd.read_csv('movies.csv', encoding = 'utf-8')
data.head()
# Out:
#   순번                             영화 제목  ...  Unnamed: 24                    메인장르
# 0  1           Spider-Man: No Way Home  ...          NaN              Ac, Ad, Fa
# 1  2                              Dune  ...          NaN            Ac, Ad, Dr\n
# 2  3                    Licorice Pizza  ...          NaN  Co\n, Dr\n, Ro\n\n\n\n
# 3  4                     Groundhog Day  ...          NaN          Co\n, Dr\n, Fa
# 4  5  Once Upon a Time in... Hollywood  ...          NaN              Co\n, Dr\n
#
# [5 rows x 26 columns]

# %% [markdown]
# 데이터셋에서 영화의 포스터 6개를 랜덤으로 받아온다.

# %%
poster = data.sample(n=6)
poster
# Out:
#       순번  ...                              메인장르
# 694  695  ...                              Dr\n
# 928  929  ...             Ani\n\n\n\n\n, Ac, Ad
# 824  825  ...                         Dr\n, War
# 911  912  ...                         Dr\n, War
# 378  379  ...  Ac, Sci\n\n\n\n\n, Thr\n\n\n\n\n
# 376  377  ...           Ad, Dr\n, His\n\n\n\n\n
#
# [6 rows x 26 columns]

# %%
# Series에 담긴 랜덤 영화값 예시
posterImage = poster['사진']

# %%
poster['영화 제목']
# Out:
# 694                    Breaking the Waves
# 928    Rupan sansei: Kariosutoro no shiro
# 824                              Lifeboat
# 911                      The Caine Mutiny
# 378                            District 9
# 376                             Apollo 13
# Name: 영화 제목, dtype: object

# %%
#1.랜덤으로 6개의 영화 정보와 포스터 보여줌

import requests
from io import BytesIO
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random
posterImage = poster['사진']

url = [1, 2, 3, 4, 5, 6]
poster = data.sample(n=6)
poster

plt.figure(figsize=(20, 15))
for i in range(6):
  url[i]=posterImage.values[i]
  # url[i]=data['사진'].loc[i]
  plt.subplot(1,6,i+1)
  text = f""" 
  {i+1}번째 영화
{poster.iloc[i, 1]}

1. 메타스코어: {poster.iloc[i, 7]} 점
  2. IMDB 평점 : {poster.iloc[i, 6]} 점
      3. 개봉연도  : {poster.iloc[i, 2]} 년도
 4. 연령제한 : 만 {poster.iloc[i, 3]}세

|장르 정보|
{poster.iloc[i, 5]} 

           """
  plt.title(text)
  plt.imshow(Image.open(BytesIO(requests.get(url[i]).content)))
  plt.axis('off')
  plt.subplots_adjust(left=0.125, bottom=0.1,  right=0.9, top=0.9, wspace=1.5, hspace=0.35)

# %%
#랜덤은 아님

import requests
from io import BytesIO
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random

url = [1, 2, 3, 4, 5, 6]
plt.figure(figsize=(20, 15))
for i in range(6):
  url[i]=data['사진'].loc[i]
  plt.subplot(1,6,i+1)
  text = f""" 
  {i+1}번째 영화
{data['영화 제목'].loc[i]}

1. 메타스코어: {data['Metascore'].loc[i]} 점
  2. IMDB 평점 : {data['IMDB RATING'].loc[i]} 점
      3. 개봉연도  : {data['개봉연도'].loc[i]} 년도
 4. 연령제한 : 만 {data['연령제한'].loc[i]}세

|장르 정보|
{data['장르'].loc[i]} 

           """
  plt.title(text)
  plt.imshow(Image.open(BytesIO(requests.get(url[i]).content)))
  plt.axis('off')
  plt.subplots_adjust(left=0.125, bottom=0.1,  right=0.9, top=0.9, wspace=1.5, hspace=0.35)

# %%
#2. 마음에 드는 영화 선택, 영화 줄거리를 볼 수 있음
movie_gn=[]
count=1
print('당신에게 알맞는 영화를 추천해드립니다.\n')

while count<3:
  gn=input(print(f'보고 싶은 2개의 영화의 해당 번호를 입력해 주세요.'))
  if gn=='1':
    movie_gn.append('1번째 영화')
    count+=1
  if gn=='2':
    movie_gn.append('2번째 영화')
    count+=1
  if gn=='3':
    movie_gn.append('3번째 영화')
    count+=1
  if gn=='4':
    movie_gn.append('4번째 영화')
    count+=1
  if gn=='5':
    movie_gn.append('5번째 영화')
    count+=1
  if gn=='6':
    movie_gn.append('6번째 영화')
    count+=1
  if count==3:
    movie_gn=", ".join(movie_gn)
    break

print(f'당신이 선택한 영화는 "{movie_gn}" 입니다.\n')

for i in range(6):
  print(f'{i+1} 번째 영화 "{data.iloc[i,1]}"의 줄거리 :',data.iloc[i,9])
# Out:
# 당신에게 알맞는 영화를 추천해드립니다.
#
# 보고 싶은 2개의 영화의 해당 번호를 입력해 주세요.
# 5
# 보고 싶은 2개의 영화의 해당 번호를 입력해 주세요.
# 6
# 당신이 선택한 영화는 "5번째 영화, 6번째 영화" 입니다.
#
# 1 번째 영화 "Spider-Man: No Way Home"의 줄거리 : With Spider-Man's identity now revealed, Peter asks Doctor Strange for help. When a spell goes wrong, dangerous foes from other worlds start to appear, forcing Peter to discover what it truly means to be Spider-Man.
# 2 번째 영화 "Dune"의 줄거리 : Feature adaptation of Frank Herbert's science fiction novel about the son of a noble family entrusted with the protection of the most valuable asset and most vital element in the galaxy.
# 3 번째 영화 "Licorice Pizza"의 줄거리 : The story of Alana Kane and Gary Valentine growing up, running around and going through the treacherous navigation of first love in the San Fernando Valley, 1973.
# 4 번째 영화 "Groundhog Day"의 줄거리 : A self-centered Pittsburgh weatherman finds himself inexplicably trapped in a small town as he lives the same day over and over again.
# ...

# %% [markdown]
# #cosine similarity를 이용한 genre 기반 영화 추천

# %%
# 장르 열 전처리
print('장르 열의 결측값의 수:',data['장르'].isnull().sum())

# 결측치, Null 값을 가진 경우에는 값 제거
data['장르'] = data['장르'].fillna('')

# tfidf(Term Frequency - Inverse Document Frequency)
tfidf = TfidfVectorizer(stop_words='english') # 불용어 제거
tfidf_matrix = tfidf.fit_transform(data['장르'])
print('TF-IDF 행렬의 크기(shape) :',tfidf_matrix.shape)
# Out:
# 장르 열의 결측값의 수: 0
# TF-IDF 행렬의 크기(shape) : (1000, 23)

# %% [markdown]
# TF-IDF 행렬의 크기는 1,000의 행을 가지고 23의 열을 가지는 행렬입니다. 다시 말해 1,000개의 영화를 표현하기 위해서 총 23개의 단어가 사용되었음을 의미합니다. 이제 1,000개의 문서 벡터에 대해서 상호 간의 코사인 유사도를 구합니다.

# %%
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)
print('코사인 유사도 연산 결과 :',cosine_sim.shape)
# Out:
# 코사인 유사도 연산 결과 : (1000, 1000)

# %%
title_to_index = dict(zip(data['영화 제목'], data.index))

idx = title_to_index['Modern Times']
print(idx)
# Out:
# 646

# %%
def get_recommendations(title, cosine_sim=cosine_sim):
    # 선택한 영화의 타이틀로부터 해당 영화의 인덱스를 받아온다.
    idx = title_to_index[title]

    # 해당 영화와 모든 영화와의 유사도를 가져온다.
    sim_scores = list(enumerate(cosine_sim[idx]))

    # 유사도에 따라 영화들을 정렬한다.
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # 가장 유사한 10개의 영화를 받아온다.
    sim_scores = sim_scores[1:11]

    # 가장 유사한 10개의 영화의 인덱스를 얻는다.
    movie_indices = [idx[0] for idx in sim_scores]

    # 가장 유사한 10개의 영화의 제목을 리턴한다.
    return data['영화 제목'].iloc[movie_indices]

# %%
# 영화 제목의 인덱스를 리턴
get_recommendations(poster['영화 제목'].iloc[0]) # ----------------------------사용자가 선택한 값으로 변경
# Out:
# 90                                                Druk
# 127                                    The Truman Show
# 167                                 Dead Poets Society
# 228                                 The Breakfast Club
# 253                                  Captain Fantastic
# 282    Birdman or (The Unexpected Virtue of Ignorance)
# 285                               The Royal Tenenbaums
# 288                               Little Miss Sunshine
# 331                                Lost in Translation
# 339                                           3 Idiots
# Name: 영화 제목, dtype: object

# %% [markdown]
# # 줄거리 기반 영화 추천

# %%
# !apt-get update
# !apt-get install g++ openjdk-8-jdk python-dev python3-dev
# !pip3 install JPype1-py3 # 파이썬에서 자바 클래스를 호출해 사용할 수 있도록 해준다.
# !pip3 install konlpy # 코엔엘파이 : 한국어 정보처리를 위한 파이썬 패키지.
# !JAVA_HOME="C:\eclipse-jee-photon-R-win32-x86_64\Java\jdk1.8.0_181"
# Out:
# Get:1 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:2 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:4 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:5 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:6 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:7 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease [15.9 kB]
# Get:8 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Get:9 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:11 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# ...

# %%
# 줄거리 데이터 전처리
data['줄거리'] = data['줄거리'].fillna('')

# %%
data['줄거리'].count()
# Out:
# 1000

# %%
# 줄거리를 list 형태로 담아서 tfidf_vectorizer.fit_transform에 담아준다.
summary = data['줄거리'].tolist()
s = summary

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# 1000개 영화 줄거리에 대한 유사도 값

tfidf_vectorizer = TfidfVectorizer(min_df=1)
tfidf_matrix = tfidf_vectorizer.fit_transform(s)
doc_similarities = (tfidf_matrix * tfidf_matrix.T)

print(doc_similarities.toarray())
# Out:
# [[1.         0.00594432 0.         ... 0.03158252 0.04355392 0.01437061]
#  [0.00594432 1.         0.05565083 ... 0.01329739 0.04442144 0.02131569]
#  [0.         0.05565083 1.         ... 0.03823532 0.05962642 0.02238273]
#  ...
#  [0.03158252 0.01329739 0.03823532 ... 1.         0.08507629 0.        ]
#  [0.04355392 0.04442144 0.05962642 ... 0.08507629 1.         0.05930225]
#  [0.01437061 0.02131569 0.02238273 ... 0.         0.05930225 1.        ]]

# %%
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)
print(cosine_sim.shape)
# Out:
# (1000, 1000)

# %%
indices = pd.Series(data.index, index=data['영화 제목'])
print(indices.head())
# Out:
# 영화 제목
# Spider-Man: No Way Home             0
# Dune                                1
# Licorice Pizza                      2
# Groundhog Day                       3
# Once Upon a Time in... Hollywood    4
# dtype: int64

# %%
# 모든 영화에 대해서 해당 영화와의 유사도를 구합니다.
title = 'Spider-Man: No Way Home'
idx = indices[title]
sim_scores = cosine_sim[idx]
print(sim_scores[:5])
# Out:
# [1.         0.00594432 0.         0.         0.00754998]

# %%
sim_scores = list(enumerate(sim_scores))
print(sim_scores[:5])
# Out:
# [(0, 1.0000000000000002), (1, 0.005944319070100279), (2, 0.0), (3, 0.0), (4, 0.007549978916938406)]

# %%
# 유사도에 따라 영화들을 정렬합니다.
sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
print(sim_scores[:5])
# Out:
# [(0, 1.0000000000000002), (32, 0.24004907800829448), (602, 0.15600406386087562), (253, 0.10928412799827325), (791, 0.10803921666697294)]

# %%
# 가장 유사한 5개의 영화를 받아옵니다.
sim_scores = sim_scores[1:6]
print(sim_scores)
# Out:
# [(32, 0.24004907800829448), (602, 0.15600406386087562), (253, 0.10928412799827325), (791, 0.10803921666697294), (880, 0.0956483258902169)]

# %%
# 가장 유사한 5개의 영화의 인덱스를 받아옵니다.
movie_indices = [i[0] for i in sim_scores]
print(movie_indices) #[448, 485, 591, 314, 427]
print(data['영화 제목'].iloc[movie_indices])
# Out:
# [32, 602, 253, 791, 880]
# 32     Spider-Man: Into the Spider-Verse
# 602                    Finding Neverland
# 253                    Captain Fantastic
# 791                          Kumonosu-jô
# 880                           Hera Pheri
# Name: 영화 제목, dtype: object

# %% [markdown]
# # 상관분석

# %%
# 데이터에서 숫자로 이루어진 컬럼만을 뽑는다.
train_df_number = data.select_dtypes(np.number) 
train_df_number
# Out:
#      개봉연도  연령제한  상영시간  ...  Unnamed: 22  Unnamed: 23  Unnamed: 24
# 0    2021    12   148  ...          NaN          NaN          NaN
# 1    2021    12   155  ...          NaN          NaN          NaN
# 2    2021    15   133  ...          NaN          NaN          NaN
# 3    1993    15   101  ...          NaN          NaN          NaN
# 4    2019    18   161  ...          NaN          NaN          NaN
# ..    ...   ...   ...  ...          ...          ...          ...
# 995  2012    12   125  ...          NaN          NaN          NaN
# 996  2013    15   144  ...          NaN          NaN          NaN
# 997  2009    15   128  ...          NaN          NaN          NaN
# 998  1971    12   122  ...          NaN          NaN          NaN
# 999  1999    15   174  ...          NaN          NaN          NaN
#
# [1000 rows x 11 columns]

# %%
import seaborn as sns

interest_coloumns = ['개봉연도','연령제한','IMDB RATING', '총수입', '투표']

sns.pairplot(train_df_number[interest_coloumns])

# %% [markdown]
# 보통 0.4이상이면 두 개의 변수간에 상관성이 있다고 얘기합니다.
# 투표와 총수입의 상관관계가 0.52로 높은 편으로 보입니다.

# %%
train_df_number.corr()['총수입']
train_df_number.corr()['총수입'].sort_values()
# Out:
# 연령제한          -0.183701
# Metascore     -0.077176
# IMDB RATING    0.120629
# 상영시간           0.176032
# 개봉연도           0.245248
# 투표             0.520168
# 총수입            1.000000
# Unnamed: 21         NaN
# Unnamed: 22         NaN
# Unnamed: 23         NaN
# Unnamed: 24         NaN
# Name: 총수입, dtype: float64

# %%
train_df_number.corr()['개봉연도']
train_df_number.corr()['개봉연도'].sort_values()
# Out:
# Metascore     -0.274250
# IMDB RATING   -0.089191
# 연령제한           0.084889
# 상영시간           0.184379
# 투표             0.239371
# 총수입            0.245248
# 개봉연도           1.000000
# Unnamed: 21         NaN
# Unnamed: 22         NaN
# Unnamed: 23         NaN
# Unnamed: 24         NaN
# Name: 개봉연도, dtype: float64

# %%
train_df_number.corr()['IMDB RATING']
train_df_number.corr()['IMDB RATING'].sort_values()
# Out:
# 개봉연도          -0.089191
# 연령제한          -0.060514
# Metascore      0.255732
# IMDB RATING    1.000000
# Name: IMDB RATING, dtype: float64

# %% [markdown]
# ###줄거리 뽑아 정리

# %%
df = pd.read_csv('movies.csv', encoding = 'utf-8')
df.head()
# Out:
#   순번  ...                                                 링크
# 0  1  ...  https://www.imdb.com/title/tt10872600/?ref_=ad...
# 1  2  ...  https://www.imdb.com/title/tt1160419/?ref_=adv...
# 2  3  ...  https://www.imdb.com/title/tt11271038/?ref_=ad...
# 3  4  ...  https://www.imdb.com/title/tt0107048/?ref_=adv...
# 4  5  ...  https://www.imdb.com/title/tt7131622/?ref_=adv...
#
# [5 rows x 21 columns]

# %%
story_df = df['줄거리']
print(type(story_df))
print(story_df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-78a39ddcdcb8> in <module>()
# ----> 1 story_df = df['줄거리']
#       2 print(type(story_df))
#       3 print(story_df.head())
#
# NameError: name 'df' is not defined

# %%
#토큰화 
from tensorflow.keras.preprocessing.text import text_to_word_sequence

# %%
for i in range(0,1000):
  print(f'{i+1}번째 영화의 줄거리 토큰화 시킨 결과 :',text_to_word_sequence(df.iloc[i,9]))

# %% [markdown]
# #데이터 분석

# %%
train_df_number = data.select_dtypes(np.number) 
train_df_number

# %%
import seaborn as sns

interest_coloumns = ['개봉연도','연령제한','IMDB RATING', '총수입', '투표']

sns.pairplot(train_df_number[interest_coloumns])

# %%
train_df_number.corr()['총수입']
train_df_number.corr()['총수입'].sort_values()

# %%
train_df_number.corr()['개봉연도']
train_df_number.corr()['개봉연도'].sort_values()

# %%
train_df_number.corr()['IMDB RATING']
train_df_number.corr()['IMDB RATING'].sort_values()

# %% [markdown]
# #데이터 시각화

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

plt.figure(figsize = (36,24))
plt.title('스코어,수익')
plt.plot(data['순번'],data['Metascore'],'r',label = '메타스코어')
plt.plot(data['순번'],data['IMDB RATING'],'g',label = 'IMDB 레이팅')
plt.plot(data['순번'],data['총수입'],'b',label = '총수익')
plt.legend()
plt.show()

# %%
data['순번']
# Out:
# 0             1
# 1             2
# 2             3
# 3             4
# 4             5
#          ...
# 995         996
# 996         997
# 997         998
# 998         999
# 999    1,000.00
# Name: 순번, Length: 1000, dtype: object

# %%
###데이터 시각화

import matplotlib as mpl
import matplotlib.pyplot as plt


plt.figure(figsize = (36,12))
plt.title('스코어')
plt.plot(data['순번'],data['Metascore'],'r',label = '메타스코어')
plt.plot(data['순번'],10*data['IMDB RATING'],'g',label = 'IMDB 레이팅')

# %%
plt.figure(figsize = (36,12))
plt.title('스코어')
plt.scatter(10*data['IMDB RATING'],data['Metascore'])

# %%
plt.figure(figsize = (36,12))
plt.title('투표수와 수익의 관계')
plt.scatter(data['투표'],data['총수입'])

# %%
(10*data['IMDB RATING']-data['Metascore'])**2
# Out:
# 0      256.0
# 1       49.0
# 2      121.0
# 3       64.0
# 4       49.0
#        ...
# 995      0.0
# 996      0.0
# 997      0.0
# 998      0.0
# 999      0.0
# Length: 1000, dtype: float64

# %%
year_data = data.groupby('개봉연도').size()
plt.figure(figsize = (20, 6))
year_data.plot.bar()

# %%
data.groupby('영화 제목')['IMDB RATING'].mean().sort_values(ascending=False).head(20)

data.groupby('영화 제목')['Metascore'].mean().sort_values(ascending=False).head(20)

data.groupby('영화 제목')['총수입'].mean().sort_values(ascending=False).head(20)
# Out:
# 영화 제목
# Spider-Man: No Way Home                       1804.0
# Star Wars: Episode VII - The Force Awakens     937.0
# Avengers: Endgame                              858.0
# Avatar                                         761.0
# Avengers: Infinity War                         679.0
# Titanic                                        659.0
# Zack Snyder's Justice League                   658.0
# The Avengers                                   623.0
# Hamilton                                       613.0
# The Dark Knight                                535.0
# Rogue One                                      532.0
# Dakeu naiteu raijeu                            448.0
# E.T. the Extra-Terrestrial                     435.0
# Toy Story 4                                    434.0
# The Lion King                                  423.0
# Toy Story 3                                    415.0
# Captain America: Civil War                     408.0
# Jyuragi gongwon                                402.0
# ...

# %%
income_data = data.groupby('영화 제목')['총수입'].mean().sort_values(ascending=False).head(20)
income_data.plot.bar()

# %%
income_data = data.groupby('연령제한')['총수입'].mean().sort_values(ascending=False)
income_data.plot.bar()

#연령별 총수입 평균

# %%
income_data = data.groupby('장르')['총수입'].sum().sort_values(ascending=False)
income_data.plot.bar()

# %%
plt.figure(figsize = (36,12))
plt.title('수익')
plt.plot(data['투표'],data['총수입'])

# %%
(10*data['IMDB RATING']-data['Metascore'])**2
# Out:
# 0      256.0
# 1       49.0
# 2      121.0
# 3       64.0
# 4       49.0
#        ...
# 995      0.0
# 996      0.0
# 997      0.0
# 998      0.0
# 999      0.0
# Length: 1000, dtype: float64

# %%
year_data = data.groupby('개봉연도').size()
plt.figure(figsize = (20, 6))
year_data.plot.bar()

# %%
from matplotlib import pyplot as plt
import plotly.express as px
fig = plt.figure(figsize=(10,7))
genre= ['Action','Adventure', 'Fanatsy',  'Drama', 'Comedy','Romance','Musical','Crime','Music','Family','Biography','Sci-Fi','War','Thriller','Mystery','Hisory','Animation','Horror','Western','Sports','Film-Noir']
cnt = [1015,5854,592,734,234,128,17,205,53,12,107,65,53,133,100,54,83,36,21,16,22]

plt.pie(cnt, labels = genre)
plt.axis('equal')

plt.show()
